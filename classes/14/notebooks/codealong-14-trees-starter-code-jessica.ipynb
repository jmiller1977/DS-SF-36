# %% [markdown]
# # DS-SF-36 | 14 | Trees | Codealong | Starter Code

# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 50)

import math

# %% [markdown]
# ## Part A | The 2008 Democratic Primaries

# %% [markdown]
# (dataset adapted from http://www.stat.ucla.edu/~cocteau/primaries.csv)

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-14-2008-democrat-primaries.csv'))

# %%
df.columns
# Out:
# Index([u'fips', u'county_name', u'state_postal', u'region', u'election_date',
#        u'racetype', u'tvotes', u'clinton', u'obama', u'edwards', u'margin',
#        u'winner', u'POP05_SQMI', u'popUnder30_00', u'pop65up_00',
#        u'presVote04', u'kerry04', u'Bush04', u'pres04margin', u'pres04winner',
#        u'pop06', u'pop00', u'hisp06', u'white06', u'black06', u'indian06',
#        u'asian06', u'hawaii06', u'mixed06', u'pct_less_30k', u'pct_more_100k',
#        u'pct_hs_grad', u'pct_labor_force', u'pct_homeowner', u'unempFeb07',
#        u'unempFeb08', u'unempChg', u'pctUnins00', u'subForPctHomes',
#        u'poverty05', u'median_hhi05', u'Catholic', u'So.Bapt.Conv',
#        u'Un.Methodist', u'E.L.C.A.', u'Construction', u'Manufacturing',
#        u'FinancialActivities', u'GoodsProducing', u'ServiceProviding'],
#       dtype='object')

# %%
df.head()
# Out:
#    fips county_name state_postal region election_date racetype  tvotes  \
# 0  1001     Autauga           AL      S        2/5/08  Primary    4118
# 1  1003     Baldwin           AL      S        2/5/08  Primary   12085
# 2  1005     Barbour           AL      S        2/5/08  Primary    3823
# 3  1007        Bibb           AL      S        2/5/08  Primary    1751
# 4  1009      Blount           AL      S        2/5/08  Primary    3471
#
#    clinton  obama  edwards    margin   winner  POP05_SQMI  popUnder30_00  \
# 0     1760   2268       57  0.123361    obama        78.9           30.3
# 1     6259   5450      227 -0.066942  clinton        97.0           27.2
# 2     1322   2393       60  0.280146    obama        32.3           31.4
# 3      922    755       44 -0.095374  clinton        33.4           32.8
# 4     2735    617       75 -0.610199  clinton        80.7           30.2
#
#    pop65up_00  presVote04   kerry04    Bush04  pres04margin pres04winner  \
# 0        10.2     20081.0  0.236940  0.756735      0.519795         bush
# 1        15.5     69320.0  0.225029  0.764152      0.539123         bush
# 2        13.3     10777.0  0.448362  0.547369      0.099007         bush
# 3        11.6      7600.0  0.274868  0.720000      0.445132         bush
# 4        12.9     21504.0  0.183129  0.808501      0.625372         bush
#
#       pop06     pop00  hisp06   white06  black06  indian06  asian06  hawaii06  \
# 0   49730.0   43911.0   827.0   39368.0   8559.0     203.0    271.0      12.0
# 1  169162.0  141423.0  4176.0  145687.0  16301.0     770.0    679.0      42.0
# 2   28171.0   29044.0   953.0   13793.0  13035.0     115.0     84.0       6.0
# 3   21482.0   19939.0   304.0   16266.0   4705.0      63.0     25.0       2.0
# 4   56436.0   51229.0  3752.0   51031.0    872.0     238.0    125.0       7.0
#
#    mixed06  pct_less_30k  pct_more_100k  pct_hs_grad  pct_labor_force  \
# 0    490.0        0.3418       0.075945       0.7872           0.6515
# 1   1507.0        0.3582       0.094931       0.8202           0.5982
# 2    185.0        0.5682       0.050326       0.6465           0.4802
# 3    117.0        0.4746       0.035216       0.6319           0.5289
# 4    411.0        0.4149       0.050123       0.7045           0.6057
#
#    pct_homeowner  unempFeb07  unempFeb08  unempChg  pctUnins00  \
# 0         0.8083         3.0         3.6       0.6        12.8
# 1         0.7958         3.1         3.4       0.3        13.8
# 2         0.7316         5.0         7.1       2.1        19.4
# 3         0.8019         3.7         4.2       0.5        16.5
# 4         0.8349         3.1         3.3       0.2        15.7
#
#    subForPctHomes  poverty05  median_hhi05  Catholic  So.Bapt.Conv  \
# 0            0.07       10.4         45019  0.034119      0.337226
# 1            0.00       11.4         42804  0.074650      0.197906
# 2            6.40       22.4         29534  0.009126      0.260900
# 3            0.10       16.6         34212  0.000000      0.386248
# 4            0.04       11.4         40588  0.007369      0.355872
#
#    Un.Methodist  E.L.C.A.  Construction  Manufacturing  FinancialActivities  \
# 0      0.075680  0.000000      6.797467      17.577510             5.366229
# 1      0.070455  0.001068     10.558143       9.230177             7.923872
# 2      0.062367  0.000000      2.501616      45.067103             3.379843
# 3      0.023672  0.000000     20.750603      15.723631             3.477562
# 4      0.071182  0.000000      9.754604      22.763883             4.300316
#
#    GoodsProducing  ServiceProviding
# 0       26.776236         73.223764
# 1       21.282357         78.717643
# 2       51.275520         48.724480
# 3       42.557099         57.442901
# 4       34.129339         65.870661

# %%
df.winner.value_counts(dropna=False)
# Out:
# clinton    1210
# obama      1031
# NaN          20
# Name: winner, dtype: int64

# %%
df['c']=(df.winner=='obama')*1.

# %%
df.c
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 2256    0.0
# 2257    1.0
# 2258    1.0
# 2259    1.0
# 2260    0.0
# Name: c, Length: 2261, dtype: float64

# %%
# TODO

# %% [markdown]
# ### First cut: Is a county more than 20% black?

# %%
# TODO

# %% [markdown]
# #### First cut/right node

# %%
# TODO
df.columns
# Out:
# Index([u'fips', u'county_name', u'state_postal', u'region', u'election_date',
#        u'racetype', u'tvotes', u'clinton', u'obama', u'edwards', u'margin',
#        u'winner', u'POP05_SQMI', u'popUnder30_00', u'pop65up_00',
#        u'presVote04', u'kerry04', u'Bush04', u'pres04margin', u'pres04winner',
#        u'pop06', u'pop00', u'hisp06', u'white06', u'black06', u'indian06',
#        u'asian06', u'hawaii06', u'mixed06', u'pct_less_30k', u'pct_more_100k',
#        u'pct_hs_grad', u'pct_labor_force', u'pct_homeowner', u'unempFeb07',
#        u'unempFeb08', u'unempChg', u'pctUnins00', u'subForPctHomes',
#        u'poverty05', u'median_hhi05', u'Catholic', u'So.Bapt.Conv',
#        u'Un.Methodist', u'E.L.C.A.', u'Construction', u'Manufacturing',
#        u'FinancialActivities', u'GoodsProducing', u'ServiceProviding', u'c'],
#       dtype='object')

# %%
df['pct_black06']=df.black06/df.pop06

# %%
parent_df = df

# %%
left_child_df = parent_df[parent_df.pct_black06<=.2]

# %%
len(left_child_df)
# Out:
# 1810

# %%
right_child_df = parent_df[parent_df.pct_black06>.2]
len(right_child_df)
# Out:
# 450

# %%
right_child_df = parent_df.drop(left_child_df.index)
len(right_child_df)
# Out:
# 451

# %%
left_child_df.index
# Out:
# Int64Index([   0,    1,    4,    7,    9,   10,   13,   14,   15,   16,
#             ...
#             2251, 2252, 2253, 2254, 2255, 2256, 2257, 2258, 2259, 2260],
#            dtype='int64', length=1810)

# %%
right_child_df.index
# Out:
# Int64Index([   2,    3,    5,    6,    8,   11,   12,   17,   18,   20,
#             ...
#             2107, 2110, 2111, 2112, 2114, 2116, 2118, 2119, 2122, 2206],
#            dtype='int64', length=451)

# %%
def obama_vs_clinton(df):
    obama = (df.c == 1).sum()
    clinton = (df.c == 0).sum()
    if obama > clinton:
        print 'Obama wins these counties {} to {}.'.format(obama, clinton)
    elif clinton > obama:
        print 'Clinton wins these counties {} to {}.'.format(clinton, obama)
    else:
        print 'Obama and Clinton tie in these counties {} {}.'.format(obama, clinton)

# %%
obama_vs_clinton(right_child_df)
# Out:
# Obama wins these counties 381 to 70.

# %% [markdown]
# ### Second cut: Is high school graduation rate higher than 78%?

# %%
left_child_df
# Out:
#        fips county_name state_postal region election_date racetype  tvotes  \
# 0      1001     Autauga           AL      S        2/5/08  Primary    4118
# 1      1003     Baldwin           AL      S        2/5/08  Primary   12085
# 4      1009      Blount           AL      S        2/5/08  Primary    3471
# 7      1015     Calhoun           AL      S        2/5/08  Primary   11699
# 9      1019    Cherokee           AL      S        2/5/08  Primary    2689
# ...     ...         ...          ...    ...           ...      ...     ...
# 2256  56037  Sweetwater           WY      W        3/8/08   Caucus     596
# 2257  56039       Teton           WY      W        3/8/08   Caucus    1150
# 2258  56041       Uinta           WY      W        3/8/08   Caucus     168
# 2259  56043    Washakie           WY      W        3/8/08   Caucus      98
# 2260  56045      Weston           WY      W        3/8/08   Caucus      68
#
#       clinton  obama  edwards    margin   winner  POP05_SQMI  popUnder30_00  \
# 0        1760   2268       57  0.123361    obama        78.9           30.3
# 1        6259   5450      227 -0.066942  clinton        97.0           27.2
# 4        2735    617       75 -0.610199  clinton        80.7           30.2
# 7        5942   5471      154 -0.040260  clinton       184.1           30.5
# 9        2040    485      105 -0.578282  clinton        41.0           27.8
# ...       ...    ...      ...       ...      ...         ...            ...
# 2256      342    254        0 -0.147651  clinton         3.6           29.7
# 2257      231    919        0  0.598261    obama         4.5           38.6
# 2258       45    123        0  0.464286    obama         9.6           28.5
# 2259       40     58        0  0.183673    obama         3.6           23.6
# 2260       40     28        0 -0.176471  clinton         2.8           24.7
#
#       pop65up_00  presVote04   kerry04    Bush04  pres04margin pres04winner  \
# 0           10.2     20081.0  0.236940  0.756735      0.519795         bush
# 1           15.5     69320.0  0.225029  0.764152      0.539123         bush
# 4           12.9     21504.0  0.183129  0.808501      0.625372         bush
# 7           14.1     45249.0  0.333333  0.658887      0.325554         bush
# 9           15.9      9049.0  0.335949  0.654547      0.318599         bush
# ...          ...         ...       ...       ...           ...          ...
# 2256         8.0     16272.0  0.320059  0.654683      0.334624         bush
# 2257         6.9     11359.0  0.525751  0.451096     -0.074654        kerry
# 2258         7.0      8081.0  0.224601  0.752506      0.527905         bush
# 2259        15.9      4114.0  0.207827  0.777832      0.570005         bush
# 2260        15.6      3392.0  0.170991  0.807488      0.636498         bush
#
#          pop06     pop00  hisp06   white06  black06     ...       hawaii06  \
# 0      49730.0   43911.0   827.0   39368.0   8559.0     ...           12.0
# 1     169162.0  141423.0  4176.0  145687.0  16301.0     ...           42.0
# 4      56436.0   51229.0  3752.0   51031.0    872.0     ...            7.0
# 7     112903.0  111392.0  2399.0   85993.0  22178.0     ...           67.0
# 9      24863.0   24059.0   273.0   22890.0   1358.0     ...            0.0
# ...        ...       ...     ...       ...      ...     ...            ...
# 2256   38763.0   37504.0  4171.0   32976.0    347.0     ...           29.0
# 2257   19288.0   18359.0  2253.0   16620.0     39.0     ...            5.0
# 2258   20213.0   19710.0  1318.0   18351.0     20.0     ...           11.0
# 2259    7819.0    8265.0  1029.0    6577.0      8.0     ...            0.0
# 2260    6762.0    6643.0   175.0    6395.0      9.0     ...            1.0
#
#       mixed06  pct_less_30k  pct_more_100k  pct_hs_grad  pct_labor_force  \
# 0       490.0        0.3418       0.075945       0.7872           0.6515
# 1      1507.0        0.3582       0.094931       0.8202           0.5982
# 4       411.0        0.4149       0.050123       0.7045           0.6057
# 7      1016.0        0.4723       0.059277       0.7390           0.5783
# 9       180.0        0.4853       0.036427       0.6352           0.5496
# ...       ...           ...            ...          ...              ...
# 2256    534.0        0.3005       0.082595       0.8737           0.7057
# 2257    149.0        0.2299       0.187581       0.9471           0.7941
# 2258    272.0        0.3320       0.050847       0.8476           0.7127
# 2259     90.0        0.4375       0.073467       0.8562           0.6687
# 2260     74.0        0.4619       0.054525       0.8520           0.6001
#
#       pct_homeowner  unempFeb07  unempFeb08  unempChg  pctUnins00  \
# 0            0.8083         3.0         3.6       0.6        12.8
# 1            0.7958         3.1         3.4       0.3        13.8
# 4            0.8349         3.1         3.3       0.2        15.7
# 7            0.7249         3.7         3.9       0.2        15.0
# 9            0.8172         3.7         4.3       0.6        15.0
# ...             ...         ...         ...       ...         ...
# 2256         0.7509         2.4         2.6       0.2        15.0
# 2257         0.5484         2.2         2.3       0.1        10.0
# 2258         0.7516         3.0         3.5       0.5        15.5
# 2259         0.7312         4.4         4.5       0.1        14.8
# 2260         0.7797         3.5         3.6       0.1        13.7
#
#       subForPctHomes  poverty05  median_hhi05  Catholic  So.Bapt.Conv  \
# 0               0.07       10.4         45019  0.034119      0.337226
# 1               0.00       11.4         42804  0.074650      0.197906
# 4               0.04       11.4         40588  0.007369      0.355872
# 7               0.09       16.9         35937  0.007270      0.452556
# 9               0.00       16.2         33858  0.000000      0.416166
# ...              ...        ...           ...       ...           ...
# 2256            0.00        7.6         57211  0.268391      0.044107
# 2257            0.00        6.1         60314  0.095282      0.005370
# 2258            0.00       10.5         48557  0.093202      0.040067
# 2259            0.00       12.6         41584  0.144891      0.060803
# 2260            0.00        9.4         40736  0.120710      0.011740
#
#       Un.Methodist  E.L.C.A.  Construction  Manufacturing  \
# 0         0.075680  0.000000      6.797467      17.577510
# 1         0.070455  0.001068     10.558143       9.230177
# 4         0.071182  0.000000      9.754604      22.763883
# 7         0.063511  0.002869      4.152047      19.758792
# 9         0.084751  0.000000      4.429688      28.864420
# ...            ...       ...           ...            ...
# 2256      0.005663  0.007923      9.959176       6.269186
# 2257      0.003123  0.010136     13.685720       0.751867
# 2258      0.000000  0.008307     16.410946       3.505822
# 2259      0.065509  0.039088      9.949833      13.033027
# 2260      0.080524  0.052830      7.336489       7.766781
#
#       FinancialActivities  GoodsProducing  ServiceProviding    c  pct_black06
# 0                5.366229       26.776236         73.223764  1.0     0.172109
# 1                7.923872       21.282357         78.717643  0.0     0.096363
# 4                4.300316       34.129339         65.870661  0.0     0.015451
# 7                3.544540       24.312853         75.687147  0.0     0.196434
# 9                4.160713       37.984366         62.015634  0.0     0.054619
# ...                   ...             ...               ...  ...          ...
# 2256             4.383050       42.670654         57.329346  0.0     0.008952
# 2257             5.465895       14.914934         85.085066  1.0     0.002022
# 2258             5.170457       32.132498         67.867502  1.0     0.000989
# 2259             6.323161       34.040552         65.959448  1.0     0.001023
# 2260             5.249570       33.584337         66.415663  0.0     0.001331
#
# [1810 rows x 52 columns]

# %%
# TODO
parent_df = left_child_df
left_child_df = parent_df[parent_df.pct_hs_grad<=.78]
right_child_df = parent_df.drop(left_child_df.index)

# %%
parent_df.head()
# Out:
#    fips county_name state_postal region election_date racetype  tvotes  \
# 0  1001     Autauga           AL      S        2/5/08  Primary    4118
# 1  1003     Baldwin           AL      S        2/5/08  Primary   12085
# 4  1009      Blount           AL      S        2/5/08  Primary    3471
# 7  1015     Calhoun           AL      S        2/5/08  Primary   11699
# 9  1019    Cherokee           AL      S        2/5/08  Primary    2689
#
#    clinton  obama  edwards    margin   winner  POP05_SQMI  popUnder30_00  \
# 0     1760   2268       57  0.123361    obama        78.9           30.3
# 1     6259   5450      227 -0.066942  clinton        97.0           27.2
# 4     2735    617       75 -0.610199  clinton        80.7           30.2
# 7     5942   5471      154 -0.040260  clinton       184.1           30.5
# 9     2040    485      105 -0.578282  clinton        41.0           27.8
#
#    pop65up_00  presVote04   kerry04    Bush04  pres04margin pres04winner  \
# 0        10.2     20081.0  0.236940  0.756735      0.519795         bush
# 1        15.5     69320.0  0.225029  0.764152      0.539123         bush
# 4        12.9     21504.0  0.183129  0.808501      0.625372         bush
# 7        14.1     45249.0  0.333333  0.658887      0.325554         bush
# 9        15.9      9049.0  0.335949  0.654547      0.318599         bush
#
#       pop06     pop00  hisp06   white06  black06     ...       hawaii06  \
# 0   49730.0   43911.0   827.0   39368.0   8559.0     ...           12.0
# 1  169162.0  141423.0  4176.0  145687.0  16301.0     ...           42.0
# 4   56436.0   51229.0  3752.0   51031.0    872.0     ...            7.0
# 7  112903.0  111392.0  2399.0   85993.0  22178.0     ...           67.0
# 9   24863.0   24059.0   273.0   22890.0   1358.0     ...            0.0
#
#    mixed06  pct_less_30k  pct_more_100k  pct_hs_grad  pct_labor_force  \
# 0    490.0        0.3418       0.075945       0.7872           0.6515
# 1   1507.0        0.3582       0.094931       0.8202           0.5982
# 4    411.0        0.4149       0.050123       0.7045           0.6057
# 7   1016.0        0.4723       0.059277       0.7390           0.5783
# 9    180.0        0.4853       0.036427       0.6352           0.5496
#
#    pct_homeowner  unempFeb07  unempFeb08  unempChg  pctUnins00  \
# 0         0.8083         3.0         3.6       0.6        12.8
# 1         0.7958         3.1         3.4       0.3        13.8
# 4         0.8349         3.1         3.3       0.2        15.7
# 7         0.7249         3.7         3.9       0.2        15.0
# 9         0.8172         3.7         4.3       0.6        15.0
#
#    subForPctHomes  poverty05  median_hhi05  Catholic  So.Bapt.Conv  \
# 0            0.07       10.4         45019  0.034119      0.337226
# 1            0.00       11.4         42804  0.074650      0.197906
# 4            0.04       11.4         40588  0.007369      0.355872
# 7            0.09       16.9         35937  0.007270      0.452556
# 9            0.00       16.2         33858  0.000000      0.416166
#
#    Un.Methodist  E.L.C.A.  Construction  Manufacturing  FinancialActivities  \
# 0      0.075680  0.000000      6.797467      17.577510             5.366229
# 1      0.070455  0.001068     10.558143       9.230177             7.923872
# 4      0.071182  0.000000      9.754604      22.763883             4.300316
# 7      0.063511  0.002869      4.152047      19.758792             3.544540
# 9      0.084751  0.000000      4.429688      28.864420             4.160713
#
#    GoodsProducing  ServiceProviding    c  pct_black06
# 0       26.776236         73.223764  1.0     0.172109
# 1       21.282357         78.717643  0.0     0.096363
# 4       34.129339         65.870661  0.0     0.015451
# 7       24.312853         75.687147  0.0     0.196434
# 9       37.984366         62.015634  0.0     0.054619
#
# [5 rows x 52 columns]

# %%
obama_vs_clinton(left_child_df)
# Out:
# Clinton wins these counties 714 to 93.

# %% [markdown]
# ### Third cut: Is high school graduation rate higher than 87%?

# %%
# TODO
parent_df = right_child_df
right_child_df = parent_df[parent_df.pct_hs_grad>=.87]

# %%
obama_vs_clinton(right_child_df)
# Out:
# Obama wins these counties 176 to 36.

# %% [markdown]
# ## Part B | Building the 2008 Democratic Primaries Decision Tree by Hand

# %%
class Node:

    @staticmethod
    def root(root_df):
        cs = sorted(set(root_df.c))
        return Node(cs, root_df)

    def decision(self, left_filter):
        # Collect the observations for which the decision split is true and
        # create the corresponding left node

        left_filter = left_filter(self.df)
        left_df = self.df[left_filter]
        self.left = Node(self.cs, left_df)

        # Same thing on the right side but for the observations that don't
        # satisfy the decision split (the "else")

        right_df = self.df.drop(left_df.index)
        self.right = Node(self.cs, right_df)

        # The entropy after the decision split is the weighted average of the
        # children entropy

        self.after = (self.left.samples * self.left.before
                      + self.right.samples * self.right.before) / self.samples

        # The information gain corresponds to the entropy lost between the
        # parent node (this node and the "before") and its child (the "after")

        self.information_gain = self.before - self.after

        return self

    def __init__(self, cs, df):
        self.cs = cs
        self.df = df

        # Counts of the remaining observations in the subspace per classes
        self.counts = [(self.df.c == c).sum() for c in self.cs]

        # Number of observations in the subspace
        self.samples = sum(self.counts)

        # For empty subspaces, probabilties and entropy are set to zero
        if self.samples == 0:
            self.probabilities = [.0 for count in self.counts]
            self.before = .0
        else:
            self.probabilities = [1. * count / self.samples for count in self.counts]
            self.before = - sum(map(lambda p: p * math.log(p, 2),
                                    filter(lambda p : p > .0, self.probabilities)))

    def status(self):
        print 'classes                       =', self.cs
        print 'before:'
        print "\tparent:"
        print "\t\tsamples       =", self.samples
        print "\t\tcounts        =", self.counts
        print "\t\tprobabilities =", self.probabilities
        print "\t\tentropy       =", self.before
        print 'after:'
        print "\tleft child:"
        print "\t\tsamples       =", self.left.samples
        print "\t\tcounts        =", self.left.counts
        print "\t\tprobabilities =", self.left.probabilities
        print "\t\tentropy       =", self.left.before
        print "\tright child:"
        print "\t\tsamples       =", self.right.samples
        print "\t\tcounts        =", self.right.counts
        print "\t\tprobabilities =", self.right.probabilities
        print "\t\tentropy       =", self.right.before
        print
        print 'before entropy                =', self.before
        print 'after entropy                 =', self.after
        print 'information gain              =', self.information_gain

# %%
df.c = df.winner

# %% [markdown]
# ### First cut

# %%
# TODO
node = Node.root(df)

# %% [markdown]
# #### Candidate #1: Is a county more than 20% black?

# %%
# TODO
node.decision(lambda df: df.pct_black06<=.2).status()
# Out:
# classes                       = [nan, 'clinton', 'obama']
# before:
# 	parent:
# 		samples       = 2241
# 		counts        = [0, 1210, 1031]
# 		probabilities = [0.0, 0.53993752788933513, 0.46006247211066487]
# 		entropy       = 0.995392878882
# after:
# 	left child:
# 		samples       = 1791
# 		counts        = [0, 1141, 650]
# 		probabilities = [0.0, 0.63707426018983804, 0.36292573981016191]
# 		entropy       = 0.945085004347
# 	right child:
# 		samples       = 450
# 		counts        = [0, 69, 381]
# 		probabilities = [0.0, 0.15333333333333332, 0.84666666666666668]
# 		entropy       = 0.6181194891
#
# before entropy                = 0.995392878882
# after entropy                 = 0.879429278394
# information gain              = 0.115963600488

# %%
node.decision(lambda df: df.pct_black06<=.15).status()
# Out:
# classes                       = [nan, 'clinton', 'obama']
# before:
# 	parent:
# 		samples       = 2241
# 		counts        = [0, 1210, 1031]
# 		probabilities = [0.0, 0.53993752788933513, 0.46006247211066487]
# 		entropy       = 0.995392878882
# after:
# 	left child:
# 		samples       = 1701
# 		counts        = [0, 1096, 605]
# 		probabilities = [0.0, 0.64432686654908877, 0.35567313345091123]
# 		entropy       = 0.939032846661
# 	right child:
# 		samples       = 540
# 		counts        = [0, 114, 426]
# 		probabilities = [0.0, 0.21111111111111111, 0.78888888888888886]
# 		entropy       = 0.743601226993
#
# before entropy                = 0.995392878882
# after entropy                 = 0.891940890115
# information gain              = 0.103451988767

# %% [markdown]
# #### Candidate #2: Is high school graduation rate higher than 78%?

# %%
# TODO
node.decision(lambda df: df.pct_hs_grad>=.78).status()
# Out:
# classes                       = [nan, 'clinton', 'obama']
# before:
# 	parent:
# 		samples       = 2241
# 		counts        = [0, 1210, 1031]
# 		probabilities = [0.0, 0.53993752788933513, 0.46006247211066487]
# 		entropy       = 0.995392878882
# after:
# 	left child:
# 		samples       = 1073
# 		counts        = [0, 437, 636]
# 		probabilities = [0.0, 0.40726933830382106, 0.59273066169617894]
# 		entropy       = 0.975044372189
# 	right child:
# 		samples       = 1168
# 		counts        = [0, 773, 395]
# 		probabilities = [0.0, 0.66181506849315064, 0.33818493150684931]
# 		entropy       = 0.923071209698
#
# before entropy                = 0.995392878882
# after entropy                 = 0.947956173265
# information gain              = 0.047436705617

# %% [markdown]
# #### Candidate #3: Is high school graduation rate higher than 87%?

# %%
# TODO
node.decision(lambda df: df.pct_hs_grad>=.87).status()
# Out:
# classes                       = [nan, 'clinton', 'obama']
# before:
# 	parent:
# 		samples       = 2241
# 		counts        = [0, 1210, 1031]
# 		probabilities = [0.0, 0.53993752788933513, 0.46006247211066487]
# 		entropy       = 0.995392878882
# after:
# 	left child:
# 		samples       = 215
# 		counts        = [0, 34, 181]
# 		probabilities = [0.0, 0.15813953488372093, 0.8418604651162791]
# 		entropy       = 0.629840095336
# 	right child:
# 		samples       = 2026
# 		counts        = [0, 1176, 850]
# 		probabilities = [0.0, 0.58045409674234949, 0.41954590325765057]
# 		entropy       = 0.981241828051
#
# before entropy                = 0.995392878882
# after entropy                 = 0.947528587296
# information gain              = 0.0478642915863

# %% [markdown]
# ### Second cut

# %%
# TODO
node = node.left

# %% [markdown]
# ### Third cut

# %%
# TODO
