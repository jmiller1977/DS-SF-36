# %% [markdown]
# # DS-SF-36 | 07 | Exploratory Data Analysis | Codealong | Starter Code

# %%
import os

import math

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 40)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 40)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'storms.csv.gz'))

# %%
df.sample(10)
# Out:
#         STATE__           BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 205560     21.0  5/14/1995 0:00:00          435       EDT    73.0
# 677341     41.0  12/7/2007 0:00:00  00:00:00 AM       PST    49.0
# 728288     39.0   6/1/2008 0:00:00  21:10:00 PM       EST   135.0
# 564308      1.0  3/30/2005 0:00:00  09:00:00 PM       CST    25.0
# 692847      5.0  3/31/2008 0:00:00  19:20:00 PM       CST    75.0
# 20376      12.0   2/6/1986 0:00:00          600       CST    45.0
# 664758     27.0  6/24/2007 0:00:00  21:21:00 PM       CST   135.0
# 64127      22.0  1/24/1987 0:00:00         2042       CST    69.0
# 266702     36.0  8/23/1996 0:00:00  04:20:00 PM       EST   105.0
# 300129     40.0  6/13/1997 0:00:00  05:50:00 PM       CST    79.0
#
#           COUNTYNAME STATE              EVTYPE  BGN_RANGE BGN_AZI  \
# 205560      FRANKLIN    KY  THUNDERSTORM WINDS        0.0     NaN
# 677341        ORZ049    OR          HEAVY SNOW        0.0     NaN
# ...

# %%
df.isnull().sum()
# Out:
# STATE__            0
# BGN_DATE           0
# BGN_TIME           0
# TIME_ZONE          0
# COUNTY             0
# COUNTYNAME      1589
# STATE              0
# EVTYPE             0
# BGN_RANGE          0
# BGN_AZI       547332
# BGN_LOCATI    287743
# END_DATE      243411
# END_TIME      238978
# COUNTY_END         0
# COUNTYENDN    902297
# END_RANGE          0
# END_AZI       724837
# END_LOCATI    499225
# LENGTH             0
# WIDTH              0
# F             843563
# MAG                0
# FATALITIES         0
# INJURIES           0
# PROPDMG            0
# PROPDMGEXP    465934
# CROPDMG            0
# CROPDMGEXP    618413
# WFO           142069
# STATEOFFIC    248769
# ZONENAMES     594029
# LATITUDE          47
# LONGITUDE          0
# LATITUDE_E        40
# LONGITUDE_         0
# REMARKS       287433
# REFNUM             0
# dtype: int64

# %%
df.describe().T
# Out:
#                count           mean            std      min       25%  \
# STATE__     902297.0      31.200958      16.570178      1.0      19.0
# COUNTY      902297.0     100.642905     107.276509      0.0      31.0
# BGN_RANGE   902297.0       1.483889       5.481574      0.0       0.0
# COUNTY_END  902297.0       0.000000       0.000000      0.0       0.0
# COUNTYENDN       0.0            NaN            NaN      NaN       NaN
# END_RANGE   902297.0       0.986198       3.374106      0.0       0.0
# LENGTH      902297.0       0.230130       4.617236      0.0       0.0
# WIDTH       902297.0       7.503044      61.571363      0.0       0.0
# F            58734.0       0.914990       1.002292      0.0       0.0
# MAG         902297.0      46.899832      61.913304      0.0       0.0
# FATALITIES  902297.0       0.016785       0.765283      0.0       0.0
# INJURIES    902297.0       0.155745       5.431887      0.0       0.0
# ...

# %% [markdown]
# Variable Countyendn is null for all records.

# %%
n = df.shape[0]

for column in df.columns:
    count = df[column].isnull().sum()
    if count > 0:
        print '{:10s} {:6d} {:3.0f}%'.format(column, count, 100. * count / n)
# Out:
# COUNTYNAME   1589   0%
# BGN_AZI    547332  61%
# BGN_LOCATI 287743  32%
# END_DATE   243411  27%
# END_TIME   238978  26%
# COUNTYENDN 902297 100%
# END_AZI    724837  80%
# END_LOCATI 499225  55%
# F          843563  93%
# PROPDMGEXP 465934  52%
# CROPDMGEXP 618413  69%
# WFO        142069  16%
# STATEOFFIC 248769  28%
# ZONENAMES  594029  66%
# LATITUDE       47   0%
# LATITUDE_E     40   0%
# REMARKS    287433  32%

# %%
df[(df['INJURIES']+df['FATALITIES'])>0].STATE.value_counts()
# Out:
# TX    1767
# FL    1587
# AL     890
# IL     889
# GA     798
# CA     756
# OK     736
# MO     730
# AR     729
# LA     695
# NC     685
# MS     651
# PA     645
# TN     630
# OH     618
# IN     561
# NY     558
# KS     546
# KY     514
# SC     505
#       ...
# NH     101
# ME      97
# PR      88
# GU      81
# DE      74
# AK      74
# HI      72
# VT      53
# DC      33
# RI      17
# AM      12
# AN      12
# AS       9
# VI       6
# LM       4
# PZ       4
# MH       1
# LS       1
# PH       1
# GM       1
# Name: STATE, Length: 63, dtype: int64

# %%
df.STATE.unique()
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI',
#        'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC',
#        'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT',
#        'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'PR', 'AK', 'ST', 'AS', 'GU',
#        'MH', 'VI', 'AM', 'LC', 'PH', 'GM', 'PZ', 'AN', 'LH', 'LM', 'LE',
#        'LS', 'SL', 'LO', 'PM', 'PK', 'XX'], dtype=object)

# %%
df.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'FREEZING RAIN', 'SNOW',
#        'ICE STORM/FLASH FLOOD', 'SNOW/ICE', 'WINTER STORM',
#        'HURRICANE OPAL/HIGH WINDS', 'THUNDERSTORM WINDS', 'RECORD COLD',
#        'HURRICANE ERIN', 'HURRICANE OPAL', 'HEAVY RAIN', 'LIGHTNING',
#        'THUNDERSTORM WIND', 'DENSE FOG', 'RIP CURRENT',
#        'THUNDERSTORM WINS', 'FLASH FLOOD', 'FLASH FLOODING', 'HIGH WINDS',
#        'FUNNEL CLOUD', 'TORNADO F0', 'THUNDERSTORM WINDS LIGHTNING',
#        'THUNDERSTORM WINDS/HAIL', 'HEAT', 'WIND', 'LIGHTING',
#        'HEAVY RAINS', 'LIGHTNING AND HEAVY RAIN', 'FUNNEL', 'WALL CLOUD',
#        'FLOODING', 'THUNDERSTORM WINDS HAIL', 'FLOOD', 'COLD',
#        'HEAVY RAIN/LIGHTNING', 'FLASH FLOODING/THUNDERSTORM WI',
#        'WALL CLOUD/FUNNEL CLOUD', 'THUNDERSTORM', 'WATERSPOUT',
#        'EXTREME COLD', 'HAIL 1.75)', 'LIGHTNING/HEAVY RAIN', 'HIGH WIND',
#        'BLIZZARD', 'BLIZZARD WEATHER', 'WIND CHILL', 'BREAKUP FLOODING',
# ...

# %%
x=df[(df['INJURIES']+df['FATALITIES'])>0].EVTYPE.value_counts()
x
# Out:
# TORNADO                    7928
# LIGHTNING                  3305
# TSTM WIND                  2930
# FLASH FLOOD                 931
# THUNDERSTORM WIND           682
# EXCESSIVE HEAT              678
# HIGH WIND                   525
# FLOOD                       410
# RIP CURRENT                 399
# THUNDERSTORM WINDS          359
# HAIL                        288
# AVALANCHE                   239
# RIP CURRENTS                238
# WINTER STORM                227
# STRONG WIND                 217
# HEAT                        209
# WILDFIRE                    196
# HEAVY SNOW                  189
# WILD/FOREST FIRE            135
# HEAVY RAIN                  121
#                            ...
# GLAZE/ICE STORM               1
# EXCESSIVE RAINFALL            1
# WILD FIRES                    1
# Hurricane Edouard             1
# Whirlwind                     1
# Marine Accident               1
# THUNDERSTORM WINDSS           1
# UNSEASONABLY COLD             1
# ...

# %%
x[x>1].count()
# Out:
# 111

# %%
x[:50]
# Out:
# TORNADO                 7928
# LIGHTNING               3305
# TSTM WIND               2930
# FLASH FLOOD              931
# THUNDERSTORM WIND        682
# EXCESSIVE HEAT           678
# HIGH WIND                525
# FLOOD                    410
# RIP CURRENT              399
# THUNDERSTORM WINDS       359
# HAIL                     288
# AVALANCHE                239
# RIP CURRENTS             238
# WINTER STORM             227
# STRONG WIND              217
# HEAT                     209
# WILDFIRE                 196
# HEAVY SNOW               189
# WILD/FOREST FIRE         135
# HEAVY RAIN               121
#                         ...
# URBAN/SML STREAM FLD      43
# TROPICAL STORM            42
# HEAVY SURF/HIGH SURF      39
# WIND                      39
# DENSE FOG                 34
# HURRICANE                 31
# COLD                      31
# HEAT WAVE                 30
# TSTM WIND/HAIL            28
# HURRICANE/TYPHOON         26
# WINTER WEATHER/MIX        25
# ...

# %%
df_new=df[df.EVTYPE.isin(x[:50].index.values) == True]
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0
# 6           1.0  11/16/1951 0:00:00          100       CST     9.0
# 7           1.0   1/22/1952 0:00:00          900       CST   123.0
# 8           1.0   2/13/1952 0:00:00         2000       CST   125.0
# 9           1.0   2/13/1952 0:00:00         2000       CST    57.0
# 10          1.0   2/13/1952 0:00:00         2030       CST    43.0
# 11          1.0   2/13/1952 0:00:00         2030       CST     9.0
# 12          1.0   2/13/1952 0:00:00         2130       CST    73.0
# ...

# %%
x[x>1].index.values
# Out:
# array(['TORNADO', 'LIGHTNING', 'TSTM WIND', 'FLASH FLOOD',
#        'THUNDERSTORM WIND', 'EXCESSIVE HEAT', 'HIGH WIND', 'FLOOD',
#        'RIP CURRENT', 'THUNDERSTORM WINDS', 'HAIL', 'AVALANCHE',
#        'RIP CURRENTS', 'WINTER STORM', 'STRONG WIND', 'HEAT', 'WILDFIRE',
#        'HEAVY SNOW', 'WILD/FOREST FIRE', 'HEAVY RAIN', 'EXTREME COLD',
#        'HIGH WINDS', 'ICE STORM', 'FOG', 'EXTREME COLD/WIND CHILL',
#        'HIGH SURF', 'BLIZZARD', 'COLD/WIND CHILL', 'WINTER WEATHER',
#        'DUST STORM', 'URBAN/SML STREAM FLD', 'TROPICAL STORM',
#        'HEAVY SURF/HIGH SURF', 'WIND', 'DENSE FOG', 'HURRICANE', 'COLD',
#        'HEAT WAVE', 'TSTM WIND/HAIL', 'HURRICANE/TYPHOON',
#        'WINTER WEATHER/MIX', 'HEAVY SURF', 'LANDSLIDE', 'FLASH FLOODING',
#        'STRONG WINDS', 'FLOOD/FLASH FLOOD', 'MARINE STRONG WIND', 'GLAZE',
#        'EXTREME WINDCHILL', 'ICY ROADS', 'EXTREME HEAT', 'DUST DEVIL',
#        'DRY MICROBURST', 'MARINE THUNDERSTORM WIND', 'SNOW', 'STORM SURGE',
# ...

# %%
official_event_types = [
    'Astronomical Low Tide', 'Avalanche',
    'Blizzard', 'Coastal Flood', 'Cold/Wind Chill', 'Debris Flow',
    'Dense Fog', 'Dense Smoke', 'Drought', 'Dust Devil', 'Dust Storm',
    'Excessive Heat', 'Extreme Cold/Wind Chill', 'Flash Flood', 'Flood',
    'Frost/Freeze', 'Funnel Cloud', 'Freezing Fog', 'Hail', 'Heat',
    'Heavy Rain', 'Heavy Snow', 'High Surf', 'High Wind',
    'Hurricane (Typhoon)', 'Ice Storm', 'Lake-Effect Snow',
    'Lakeshore Flood', 'Lightning', 'Marine Hail', 'Marine High Wind',
    'Marine Strong Wind', 'Marine Thunderstorm Wind', 'Rip Current',
    'Seiche', 'Sleet', 'Storm Surge/Tide', 'Strong Wind',
    'Thunderstorm Wind', 'Tornado', 'Tropical Depression',
    'Tropical Storm', 'Tsunami', 'Volcanic Ash', 'Waterspout', 'Wildfire',
    'Winter Storm', 'Winter Weather',

   'OTHER'
]

# %%
df.shape
# Out:
# (902297, 37)

# %%
df[df.EVTYPE.isin(official_event_types) == True]
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 217958     35.0   5/25/1995 0:00:00         1530       MST    61.0
# 249683      4.0   1/17/1996 0:00:00  07:30:00 AM       MST    15.0
# 251160      6.0   1/10/1996 0:00:00  09:00:00 AM       PST    12.0
# 251293      6.0   9/15/1996 0:00:00  10:30:00 AM       PST    73.0
# 252501      9.0   4/16/1996 0:00:00  05:00:00 AM       EST     3.0
# 252502      9.0   4/16/1996 0:00:00  05:00:00 AM       EST    13.0
# 252503      9.0   4/16/1996 0:00:00  05:00:00 AM       EST    15.0
# 252589      9.0   9/17/1996 0:00:00  09:00:00 PM       EST     1.0
# 252670     10.0  12/12/1996 0:00:00  11:00:00 PM       EST     2.0
# 253057     12.0    6/3/1996 0:00:00  04:15:00 PM       EST    71.0
# 254044     15.0   1/10/1996 0:00:00  09:00:00 PM       HST     2.0
# 254061     15.0    2/7/1996 0:00:00  12:00:00 AM       HST     1.0
# 254064     15.0   2/17/1996 0:00:00  02:00:00 AM       HST     3.0
# ...

# %%
df_new.corr()
# Out:
#              STATE__    COUNTY  BGN_RANGE  COUNTY_END  COUNTYENDN  END_RANGE  \
# STATE__     1.000000  0.171350   0.005249         NaN         NaN  -0.004822
# COUNTY      0.171350  1.000000   0.012727         NaN         NaN   0.014859
# BGN_RANGE   0.005249  0.012727   1.000000         NaN         NaN   0.462368
# COUNTY_END       NaN       NaN        NaN         NaN         NaN        NaN
# COUNTYENDN       NaN       NaN        NaN         NaN         NaN        NaN
# END_RANGE  -0.004822  0.014859   0.462368         NaN         NaN   1.000000
# LENGTH     -0.005832  0.002274  -0.000908         NaN         NaN   0.006407
# WIDTH      -0.014978  0.013696   0.007271         NaN         NaN   0.029595
# F          -0.035090 -0.005635  -0.183171         NaN         NaN  -0.088857
# MAG         0.025694  0.076273   0.054114         NaN         NaN   0.078358
# FATALITIES -0.003362 -0.003663  -0.002868         NaN         NaN  -0.002086
# ...

# %%
df_new.TIME_ZONE.value_counts()
# Out:
# CST    536608
# EST    225470
# MST     66432
# PST     26907
# AST      5549
# HST      2289
# AKS      1490
# CDT       666
# EDT       539
# SST       429
# PDT       103
# MDT        95
# GST        29
# UNK         9
# UTC         4
# CSt         4
# ADT         3
# ESt         2
# ESY         1
# GMT         1
# SCT         1
# CSC         1
# Name: TIME_ZONE, dtype: int64

# %% [markdown]
# CST time zone has the highest occurance of extreme weather.

# %%
df_new[df_new.TIME_ZONE=='CST'].STATE.value_counts()
# Out:
# TX    80894
# KS    50081
# OK    46147
# MO    35145
# IA    30227
# IL    27819
# AR    26515
# NE    25333
# MN    22978
# MS    21755
# AL    21629
# WI    18941
# LA    16761
# SD    15264
# TN    15196
# ND    13518
# KY     7903
# IN     6909
# FL     5798
# GA     5380
#       ...
# NJ      844
# MA      754
# ID      674
# ME      595
# UT      471
# VT      463
# CA      419
# NH      415
# CT      332
# DE      225
# NV      223
# OR      203
# WA      147
# RI       50
# DC       37
# HI       16
# GM       16
# LM       11
# PR        1
# ST        1
# Name: STATE, Length: 54, dtype: int64

# %% [markdown]
# TX, KS and OK has the highest frequency of weather events.

# %%
df_new[df_new.TIME_ZONE=='CST'].EVTYPE.value_counts()
# Out:
# HAIL                    209467
# TSTM WIND               153588
# TORNADO                  50122
# THUNDERSTORM WIND        40058
# FLASH FLOOD              29546
# THUNDERSTORM WINDS       11417
# FLOOD                    10573
# LIGHTNING                 5964
# HIGH WIND                 3751
# WINTER STORM              3444
# HEAVY RAIN                3264
# WINTER WEATHER            2735
# HEAVY SNOW                2480
# URBAN/SML STREAM FLD      1166
# WILDFIRE                  1068
# EXCESSIVE HEAT            1029
# ICE STORM                  997
# BLIZZARD                   993
# STRONG WIND                965
# FLASH FLOODING             530
#                          ...
# HIGH WINDS                 173
# FOG                        173
# EXTREME WINDCHILL           96
# WILD/FOREST FIRE            75
# RIP CURRENT                 73
# RIP CURRENTS                50
# HURRICANE                   44
# HURRICANE/TYPHOON           36
# DUST STORM                  36
# ...

# %% [markdown]
# Most frequent occuring events are HAIL, and TSTM WIND (not in official dictionary)

# %%
pd.tools.plotting.scatter_matrix(
    df[ ['MAG','FATALITIES','INJURIES'] ],
    diagonal = 'kde')
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000003AFE63C8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003A6577F0>]], dtype=object)

# %%
df[['MAG']].boxplot(figsize = (8, 8))

# %%
df[['FATALITIES']].boxplot(figsize = (8, 8))
